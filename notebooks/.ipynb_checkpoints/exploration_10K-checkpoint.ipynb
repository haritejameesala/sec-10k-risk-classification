# %%
import pandas as pd
import numpy as np
import re

# %%
from datasets import load_dataset

ds = load_dataset(
    "winterForestStump/10-K_sec_filings",
)

# %%
df = ds["032"].to_pandas()

# %%
df["Management’s Discussion and Analysis of Financial Condition and Results of Operations"].str.len().mean()
# Out:
# 7686.0005

# %%
def create_text(row):

    parts = [
        str(row["Business"]),
        str(row["Risk Factors"]),
        str(row["Financial Statements and Supplementary Data"]),
        str(row["Management’s Discussion and Analysis of Financial Condition and Results of Operations"])
    ]

    return " ".join(parts)

# %%
df["text"] = df.apply(
    create_text,
    axis=1
)

# %%
for col in df.columns:
    print(col)
# Out:
# cik
# company_name
# filing_date
# Business
# Risk Factors
# Unresolved Staff Comments
# Properties
# Legal Proceedings
# Mine Safety Disclosures
# Market for Registrant’s Common Equity, Related Stockholder Matters and Issuer Purchases of Equity Securities
# Selected Financial Data
# Management’s Discussion and Analysis of Financial Condition and Results of Operations
# Quantitative and Qualitative Disclosures about Market Risk
# Financial Statements and Supplementary Data
# Changes in and Disagreements with Accountants on Accounting and Financial Disclosure
# Controls and Procedures
# Other Information
# Directors, Executive Officers and Corporate Governance
# Executive Compensation
# Security Ownership of Certain Beneficial Owners and Management and Related Stockholder Matters
# Certain Relationships and Related Transactions, and Director Independence
# Principal Accountant Fees and Services
# Exhibits, Financial Statement Schedules
# text

# %%
for col in df.columns:
    if df[col].dtype == "object":
        avg_len = df[col].astype(str).str.len().mean()
        print(f"{col}: {avg_len:.1f}")
# Out:
# company_name: 32.2
# Business: 4816.3
# Risk Factors: 3731.2
# Unresolved Staff Comments: 931.7
# Properties: 870.4
# Legal Proceedings: 532.4
# Mine Safety Disclosures: 873.0
# Market for Registrant’s Common Equity, Related Stockholder Matters and Issuer Purchases of Equity Securities: 3417.1
# Selected Financial Data: 1940.7
# Management’s Discussion and Analysis of Financial Condition and Results of Operations: 7686.0
# Quantitative and Qualitative Disclosures about Market Risk: 2334.4
# Financial Statements and Supplementary Data: 8546.0
# Changes in and Disagreements with Accountants on Accounting and Financial Disclosure: 1654.9
# Controls and Procedures: 3106.6
# Other Information: 1851.7
# Directors, Executive Officers and Corporate Governance: 1377.6
# Executive Compensation: 2060.1
# Security Ownership of Certain Beneficial Owners and Management and Related Stockholder Matters: 4352.6
# Certain Relationships and Related Transactions, and Director Independence: 4630.5
# Principal Accountant Fees and Services: 16763.2
# Exhibits, Financial Statement Schedules: 99989.3
# text: 24782.5

# %%
# for dds in ds:
#     df_ = ds[dds].to_pandas()
#     for col in df_.columns:
#         if df_[col].dtype == "object":
#             avg_len = df_[col].astype(str).str.len().mean()
#             print(f"{col}: {avg_len:.1f}")

# %%
df50 = ds['050']

# %% [markdown]
# Need to choose latest splits

# %%
all_splits = sorted(ds.keys(), key=lambda x: int(x), reverse=True)

# %%
max_splits = 52
selected_splits = all_splits[:max_splits]
print(f"Using {max_splits} latest splits: {selected_splits}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 max_splits = 52
# ----> 2 selected_splits = all_splits[:max_splits]
#       3 print(f"Using {max_splits} latest splits: {selected_splits}")
#
# NameError: name 'all_splits' is not defined

# %%
frames = []
for split in selected_splits:
    df_split = ds[split].to_pandas()
    df_split["split"] = split          # track which filing year
    frames.append(df_split)

# %%
df_split

# %%
frames

# %%
df = pd.concat(frames, ignore_index=True)
df

# %%
df["Management’s Discussion and Analysis of Financial Condition and Results of Operations"].str.len().mean()

# %%
print(f"Combined shape: {df.shape}")

# %%
_RE_HTML        = re.compile(r"<[^>]+>")
_RE_URL         = re.compile(r"https?://\S+|www\.\S+")
_RE_ITEM_HEADER = re.compile(r"\bitem\s+\d+[a-z]?\b\.?", re.IGNORECASE)
_RE_EXHIBIT_REF = re.compile(r"\bexhibit\s+\d+[\.\d]*\b", re.IGNORECASE)
_RE_BOILERPLATE = re.compile(
    r"(table of contents|annual report on form 10-k|"
    r"securities and exchange commission|"
    r"united states securities|"
    r"washington,?\s*d\.?c\.?|"
    r"incorporated by reference|"
    r"see note \d+|"
    r"f-\d+|"                          # financial statement page refs like F-12
    r"page \d+)",
    re.IGNORECASE
)
_RE_MONEY       = re.compile(r"\$[\d,\.]+\s*(million|billion|thousand)?", re.IGNORECASE)
_RE_PERCENT     = re.compile(r"\d+\.?\d*\s*%")
_RE_DATE        = re.compile(
    r"\b(january|february|march|april|may|june|july|august|"
    r"september|october|november|december)\s+\d{1,2},?\s+\d{4}\b",
    re.IGNORECASE
)
_RE_PURE_NUMBER = re.compile(r"\b\d[\d,\.]*\b")
_RE_WHITESPACE  = re.compile(r"\s+")
_RE_SPECIAL     = re.compile(r"[^a-z\s]")   # keep only lowercase letters + spaces

# %%
def clean_text(text: str) -> str:
    """
    Full cleaning pipeline for a single section string.
    Order matters — run structural removals before character-level cleaning.
    """
    if not isinstance(text, str) or text.strip().lower() in ("nan", "none", ""):
        return ""

    t = text

    # 1. Remove HTML/XML tags (SEC EDGAR has embedded HTML)
    t = _RE_HTML.sub(" ", t)

    # 2. Remove URLs
    t = _RE_URL.sub(" ", t)

    # 3. Remove SEC boilerplate phrases
    t = _RE_BOILERPLATE.sub(" ", t)

    # 4. Remove ITEM headers (e.g. "ITEM 1A.", "Item 7.")
    t = _RE_ITEM_HEADER.sub(" ", t)

    # 5. Remove exhibit references
    t = _RE_EXHIBIT_REF.sub(" ", t)

    # 6. Remove dollar amounts  (noise for NLP; risk is in words not numbers)
    t = _RE_MONEY.sub(" ", t)

    # 7. Remove percentages
    t = _RE_PERCENT.sub(" ", t)

    # 8. Remove standalone dates
    t = _RE_DATE.sub(" ", t)

    # 9. Remove remaining pure numbers
    t = _RE_PURE_NUMBER.sub(" ", t)

    # 10. Lowercase
    t = t.lower()

    # 11. Remove all non-alphabetic characters (punctuation, symbols)
    t = _RE_SPECIAL.sub(" ", t)

    # 12. Collapse multiple spaces / newlines to single space
    t = _RE_WHITESPACE.sub(" ", t).strip()

    return t

# %%
SECTION_COLS = {
    "risk":       "Risk Factors",
    "mda":        "Management’s Discussion and Analysis of Financial Condition and Results of Operations",
    "business":   "Business",
    "financials": "Financial Statements and Supplementary Data",
}

# %%
def extract_sections(row: pd.Series) -> dict:
    """
    Pulls the 4 relevant columns from a DataFrame row.
    Returns a dict with raw text for each section.
    """
    return {
        "raw_risk":       str(row.get(SECTION_COLS["risk"],       "") or ""),
        "raw_mda":        str(row.get(SECTION_COLS["mda"],        "") or ""),
        "raw_business":   str(row.get(SECTION_COLS["business"],   "") or ""),
        "raw_financials": str(row.get(SECTION_COLS["financials"], "") or ""),
    }

# %%
def build_combined_text(sections: dict) -> str:
    """
    Concatenates cleaned sections in priority order:
    Risk Factors > MD&A > Business > Financial Statements
    """
    cleaned = {k: clean_text(v) for k, v in sections.items()}

    parts = [
        cleaned["raw_risk"],
        cleaned["raw_mda"],
        cleaned["raw_business"],
        cleaned["raw_financials"],
    ]

    # Drop empty parts
    parts = [p for p in parts if p]
    return " ".join(parts)

# %%
sections_df = df.apply(
            lambda row: pd.Series(extract_sections(row)), axis=1
        )
sections_df

# %%
sections_df[
    (sections_df["raw_risk"].str.len() < 1000) &
    (sections_df["raw_risk"].str.len() != 0)
]["raw_risk"].to_csv("low_length_risk")
# Out:
# 34       NSTAR Electric’s future performance is subject...
# 58       Risk Factors.      You should carefully review...
# 65       There are many risks that affect our business ...
# 67       To date, we have not generated significant rev...
# 96       We operate in a business environment that invo...
#                                ...
# 36441    The following risk factors should be carefully...
# 36448    When used in this Annual Report on Form 10-K a...
# 36460    Our future success depends on our ability to d...
# 36480    Risk Factors            You should carefully c...
# 36488    In addition to factors  discussed  elsewhere i...
# Name: raw_risk, Length: 2437, dtype: object

# %%
sections_df[
    (sections_df["raw_mda"].str.len() < 1000) &
    (sections_df["raw_mda"].str.len() != 0)
]["raw_mda"].to_csv("low_length_mda")
# Out:
#                                                 raw_risk  \
# 11
# 14     Risk Factors.      Factors That May Affect Fut...
# 16         Not required for smaller reporting companies.
# 19
# 21     Factors That May Affect Future Results and the...
# ...                                                  ...
# 36484
# 36488  In addition to factors  discussed  elsewhere i...
# 36494  Table of Contents  but distribute less than 10...
# 36495  our ability to manage the financial and operat...
# 36496                              Risk Factors       39
#
#                                                  raw_mda  \
# 11     Management’s Discussion and Analysis of  Finan...
# 14     Management's Discussion and Analysis of Financ...
# 16     When used in this Annual Report, the words “ma...
# 19     The following discussion provides information ...
# 21     You should read the following discussion in co...
# ...                                                  ...
# 36484  these restaurants are less than those non-comp...
# 36488  MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANC...
# 36494  Property    Number ofRooms    Location    Acqu...
# 36495  The following discussion and analysis of finan...
# 36496  expenses consist primarily of salaries and oth...
#
#                                             raw_business  \
# 11     Honeywell International Inc. (Honeywell) is a ...
# 14     Business.      General   Cambrex Corporation (...
# 16     Business Development   TC X Calibur, Inc. was ...
# 19
# 21     General   Administaff is a human resource (“HR...
# ...                                                  ...
# 36484
# 36488  In connection with its refinancing and  reorga...
# 36494
# 36495                        Item 1A.   Risk Factors  11
# 36496                                   Business       1
#
#                                           raw_financials
# 11     Years Ended December 31                       ...
# 14
# 16     TC X CALIBUR, INC. (A Development Stage Compan...
# 19     BDO USA, LLP       Accountants and Consultants...
# 21     The information required by this Item 8 is con...
# ...                                                  ...
# 36484  Page         Report of Independent Registered ...
# 36488  Financial Statements     Management’s Report o...
# 36494
# 36495  Page   REPORT OF INDEPENDENT REGISTERED PUBLIC...
# 36496  Page     Management’s   Responsibility for Fin...
#
# [8077 rows x 4 columns]

# %%
sections_df[
    (sections_df["raw_financials"].str.len() < 1000) &
    (sections_df["raw_financials"].str.len() != 0)
]["raw_financials"].to_csv("low_length_financials")
# Out:
#                                                 raw_risk  \
# 11
# 16         Not required for smaller reporting companies.
# 19
# 31
# 34     NSTAR Electric’s future performance is subject...
# ...                                                  ...
# 36480  Risk Factors            You should carefully c...
# 36484
# 36488  In addition to factors  discussed  elsewhere i...
# 36495  our ability to manage the financial and operat...
# 36496                              Risk Factors       39
#
#                                                  raw_mda  \
# 11     Management’s Discussion and Analysis of  Finan...
# 16     When used in this Annual Report, the words “ma...
# 19     The following discussion provides information ...
# 31
# 34     Overview  NSTAR Electric Company is a regulate...
# ...                                                  ...
# 36480  The following discussion is intended to assist...
# 36484  these restaurants are less than those non-comp...
# 36488  MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANC...
# 36495  The following discussion and analysis of finan...
# 36496  expenses consist primarily of salaries and oth...
#
#                                             raw_business  \
# 11     Honeywell International Inc. (Honeywell) is a ...
# 16     Business Development   TC X Calibur, Inc. was ...
# 19
# 31     General Alveron Energy Corp. (formerly Modena ...
# 34     (a)  General Development of Business  NSTAR El...
# ...                                                  ...
# 36480  (a) The following documents are filed as part ...
# 36484
# 36488  In connection with its refinancing and  reorga...
# 36495                        Item 1A.   Risk Factors  11
# 36496                                   Business       1
#
#                                           raw_financials
# 11     Years Ended December 31                       ...
# 16     TC X CALIBUR, INC. (A Development Stage Compan...
# 19     BDO USA, LLP       Accountants and Consultants...
# 31     ALVERON ENERGY CORP. (A DEVELOPMENT STAGE COMP...
# 34     NSTAR Electric Company Consolidated Statements...
# ...                                                  ...
# 36480  The following financial statements are filed i...
# 36484  Page         Report of Independent Registered ...
# 36488  Financial Statements     Management’s Report o...
# 36495  Page   REPORT OF INDEPENDENT REGISTERED PUBLIC...
# 36496  Page     Management’s   Responsibility for Fin...
#
# [5381 rows x 4 columns]

# %%
sections_df[
    (sections_df["raw_business"].str.len() < 1000) &
    (sections_df["raw_business"].str.len() != 0)
]["raw_business"].to_csv("low_length_business")
# Out:
#                                                 raw_risk  \
# 3      In addition, the securities markets from time ...
# 11
# 14     Risk Factors.      Factors That May Affect Fut...
# 15     The following risks with respect to our propos...
# 16         Not required for smaller reporting companies.
# ...                                                  ...
# 36448  When used in this Annual Report on Form 10-K a...
# 36460  Our future success depends on our ability to d...
# 36479
# 36480  Risk Factors            You should carefully c...
# 36488  In addition to factors  discussed  elsewhere i...
#
#                                                  raw_mda  \
# 3                                                     10
# 11     Management’s Discussion and Analysis of  Finan...
# 14     Management's Discussion and Analysis of Financ...
# 15     Management’s Discussion and Analysis of Financ...
# 16     When used in this Annual Report, the words “ma...
# ...                                                  ...
# 36448  Our Management’s Discussion and Analysis of ou...
# 36460  Introduction  Management's discussion and anal...
# 36479
# 36480  The following discussion is intended to assist...
# 36488  MANAGEMENT’S DISCUSSION AND ANALYSIS OF FINANC...
#
#                                             raw_business  \
# 3      We mainly engage in the research and developme...
# 11     Honeywell International Inc. (Honeywell) is a ...
# 14     Business.      General   Cambrex Corporation (...
# 15     Company Overview   Arête Industries, Inc. was ...
# 16     Business Development   TC X Calibur, Inc. was ...
# ...                                                  ...
# 36448  INFORMATION ABOUT US  Our Company was incorpor...
# 36460  Kyphon Inc., a Delaware corporation founded in...
# 36479  Business Segments Cimarex has one reportable s...
# 36480  (a) The following documents are filed as part ...
# 36488  In connection with its refinancing and  reorga...
#
#                                           raw_financials
# 3                                                     15
# 11     Years Ended December 31                       ...
# 14
# 15     Financial Statements and Supplementary Data.   23
# 16     TC X CALIBUR, INC. (A Development Stage Compan...
# ...                                                  ...
# 36448  EFUNDS CORPORATION CONSOLIDATED BALANCE SHEETS...
# 36460  REPORTS OF MANAGEMENT   Statement of Managemen...
# 36479  Page         Independent   Auditors’ Report fo...
# 36480  The following financial statements are filed i...
# 36488  Financial Statements     Management’s Report o...
#
# [7289 rows x 4 columns]

# %%
sections_df[
    (sections_df["raw_risk"].str.len() > 1000) &
    (sections_df["raw_risk"].str.len() != 0) &
    (sections_df["raw_mda"].str.len() > 1000) &
    (sections_df["raw_mda"].str.len() != 0) &
    (sections_df["raw_financials"].str.len() > 1000) &
    (sections_df["raw_financials"].str.len() != 0) &
    (sections_df["raw_business"].str.len() > 1000) &
    (sections_df["raw_business"].str.len() != 0)
]["raw_risk"]

# %%
df_raw = pd.concat([df, sections_df], axis=1)

# %%
df_raw["clean_risk"]       = df_raw["raw_risk"].apply(clean_text)
df_raw["clean_mda"]        = df_raw["raw_mda"].apply(clean_text)
df_raw["clean_business"]   = df_raw["raw_business"].apply(clean_text)
df_raw["clean_financials"] = df_raw["raw_financials"].apply(clean_text)

# %%
df_raw
# Out:
#           cik                                 company_name filing_date  \
# 0     1306830                                Celanese CORP  2011-02-11
# 1     1324424                                Expedia, Inc.  2011-02-11
# 2     1392522     Freescale Semiconductor Holdings I, Ltd.  2011-02-11
# 3     1415936             LANDMARK ENERGY ENTERPRISE, INC.  2011-02-11
# 4     1476719         57th Street General Acquisition Corp  2011-02-11
# ...       ...                                          ...         ...
# 3495  1119951  Huifeng Bio-Pharmaceutical Technology, Inc.  2010-04-15
# 3496  1122099                             VILLAGEEDOCS INC  2010-04-15
# 3497  1123493                    China Logistics Group Inc  2010-04-15
# 3498  1125903                            SHELRON GROUP INC  2010-04-15
# 3499  1126003                         ALTERNET SYSTEMS INC  2010-04-15
#
#                                                Business  \
# 0                                 Business            3
# 1
# 2
# 3     We mainly engage in the research and developme...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Forward Looking Statements  This annual report...
#
#                                            Risk Factors  \
# 0                            Risk Factors            20
# 1
# 2
# 3     In addition, the securities markets from time ...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  The Company may be unable to market and sell i...
#
#                     Unresolved Staff Comments  \
# 0     Unresolved Staff Comments            31
# 1
# 2
# 3
# 4
# ...                                       ...
# 3495
# 3496
# 3497
# 3498
# 3499                                    None.
#
#                                              Properties  \
# 0                              Properties            32
# 1
# 2
# 3     As of October 31, 2010, we leased an office sp...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499
#
#                                       Legal Proceedings  \
# 0                       Legal Proceedings            34
# 1
# 2
# 3                                                     8
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Other than as described below, management is n...
#
#                                 Mine Safety Disclosures  \
# 0     [Removed and Reserved]            34          ...
# 1
# 2
# 3                                8              PART II
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Item 5.  Market for Common Equity and Related ...
#
#      Market for Registrant’s Common Equity, Related Stockholder Matters and Issuer Purchases of Equity Securities  \
# 0     Market for the Registrant’s Common Equity,    ...
# 1
# 2
# 3                                                     9
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499               Item 6.  Selected Financial Data  12
#
#       ...            Exhibits, Financial Statement Schedules split  \
# 0     ...  Exhibits and Financial Statement Schedule     ...   052
# 1     ...                                                      052
# 2     ...                                                      052
# 3     ...  The following documents are filed as a part of...   052
# 4     ...                                                      052
# ...   ...                                                ...   ...
# 3495  ...                                                      048
# 3496  ...                                                      048
# 3497  ...                                                      048
# 3498  ...                                                      048
# 3499  ...  EXHIBIT INDEX    Number    Exhibit Description...   048
#
#                                                raw_risk  \
# 0                            Risk Factors            20
# 1
# 2
# 3     In addition, the securities markets from time ...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  The Company may be unable to market and sell i...
#
#                                                 raw_mda  \
# 0     Management’s Discussion and Analysis of     Fi...
# 1
# 2
# 3                                                    10
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Net Loss  For the year ending December 31, 200...
#
#                                            raw_business  \
# 0                                 Business            3
# 1
# 2
# 3     We mainly engage in the research and developme...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Forward Looking Statements  This annual report...
#
#                                          raw_financials  \
# 0     Financial Statements and Supplementary Data   ...
# 1
# 2
# 3                                                    15
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Hamilton PC        2121 S. Oneida St., Suite 3...
#
#                                              clean_risk  \
# 0                                          risk factors
# 1
# 2
# 3     in addition the securities markets from time t...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  the company may be unable to market and sell i...
#
#                                               clean_mda  \
# 0     management s discussion and analysis of financ...
# 1
# 2
# 3
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  net loss for the year ending the company had a...
#
#                                          clean_business  \
# 0                                              business
# 1
# 2
# 3     we mainly engage in the research and developme...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  forward looking statements this annual report ...
#
#                                        clean_financials
# 0           financial statements and supplementary data
# 1
# 2
# 3
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  hamilton pc s oneida st suite denver co p f cp...
#
# [3500 rows x 32 columns]

# %%
df_raw["text"] = df_raw.apply(
    lambda row: " ".join(filter(None, [
        row["clean_risk"],
        row["clean_mda"],
        row["clean_business"],
        row["clean_financials"],
    ])),
    axis=1
)

# %%
df_raw
# Out:
#           cik                                 company_name filing_date  \
# 0     1306830                                Celanese CORP  2011-02-11
# 1     1324424                                Expedia, Inc.  2011-02-11
# 2     1392522     Freescale Semiconductor Holdings I, Ltd.  2011-02-11
# 3     1415936             LANDMARK ENERGY ENTERPRISE, INC.  2011-02-11
# 4     1476719         57th Street General Acquisition Corp  2011-02-11
# ...       ...                                          ...         ...
# 3495  1119951  Huifeng Bio-Pharmaceutical Technology, Inc.  2010-04-15
# 3496  1122099                             VILLAGEEDOCS INC  2010-04-15
# 3497  1123493                    China Logistics Group Inc  2010-04-15
# 3498  1125903                            SHELRON GROUP INC  2010-04-15
# 3499  1126003                         ALTERNET SYSTEMS INC  2010-04-15
#
#                                                Business  \
# 0                                 Business            3
# 1
# 2
# 3     We mainly engage in the research and developme...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Forward Looking Statements  This annual report...
#
#                                            Risk Factors  \
# 0                            Risk Factors            20
# 1
# 2
# 3     In addition, the securities markets from time ...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  The Company may be unable to market and sell i...
#
#                     Unresolved Staff Comments  \
# 0     Unresolved Staff Comments            31
# 1
# 2
# 3
# 4
# ...                                       ...
# 3495
# 3496
# 3497
# 3498
# 3499                                    None.
#
#                                              Properties  \
# 0                              Properties            32
# 1
# 2
# 3     As of October 31, 2010, we leased an office sp...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499
#
#                                       Legal Proceedings  \
# 0                       Legal Proceedings            34
# 1
# 2
# 3                                                     8
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Other than as described below, management is n...
#
#                                 Mine Safety Disclosures  \
# 0     [Removed and Reserved]            34          ...
# 1
# 2
# 3                                8              PART II
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Item 5.  Market for Common Equity and Related ...
#
#      Market for Registrant’s Common Equity, Related Stockholder Matters and Issuer Purchases of Equity Securities  \
# 0     Market for the Registrant’s Common Equity,    ...
# 1
# 2
# 3                                                     9
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499               Item 6.  Selected Financial Data  12
#
#       ... split                                           raw_risk  \
# 0     ...   052                         Risk Factors            20
# 1     ...   052
# 2     ...   052
# 3     ...   052  In addition, the securities markets from time ...
# 4     ...   052
# ...   ...   ...                                                ...
# 3495  ...   048
# 3496  ...   048
# 3497  ...   048
# 3498  ...   048
# 3499  ...   048  The Company may be unable to market and sell i...
#
#                                                 raw_mda  \
# 0     Management’s Discussion and Analysis of     Fi...
# 1
# 2
# 3                                                    10
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Net Loss  For the year ending December 31, 200...
#
#                                            raw_business  \
# 0                                 Business            3
# 1
# 2
# 3     We mainly engage in the research and developme...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Forward Looking Statements  This annual report...
#
#                                          raw_financials  \
# 0     Financial Statements and Supplementary Data   ...
# 1
# 2
# 3                                                    15
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  Hamilton PC        2121 S. Oneida St., Suite 3...
#
#                                              clean_risk  \
# 0                                          risk factors
# 1
# 2
# 3     in addition the securities markets from time t...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  the company may be unable to market and sell i...
#
#                                               clean_mda  \
# 0     management s discussion and analysis of financ...
# 1
# 2
# 3
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  net loss for the year ending the company had a...
#
#                                          clean_business  \
# 0                                              business
# 1
# 2
# 3     we mainly engage in the research and developme...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  forward looking statements this annual report ...
#
#                                        clean_financials  \
# 0           financial statements and supplementary data
# 1
# 2
# 3
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  hamilton pc s oneida st suite denver co p f cp...
#
#                                                    text
# 0     risk factors management s discussion and analy...
# 1
# 2
# 3     in addition the securities markets from time t...
# 4
# ...                                                 ...
# 3495
# 3496
# 3497
# 3498
# 3499  the company may be unable to market and sell i...
#
# [3500 rows x 33 columns]

# %%
HIGH_RISK_KEYWORDS = [
    "default", "bankruptcy", "insolvency", "litigation", "lawsuit",
    "going concern", "impairment", "restructuring", "covenant violation",
    "material weakness", "restatement", "fraud", "investigation",
    "regulatory action", "liquidity risk", "credit risk", "market risk",
    "substantial doubt", "loss from operations", "net loss",
    "negative cash flow", "decline in revenue", "adverse",
]

LOW_RISK_KEYWORDS = [
    "strong growth", "record revenue", "increased profitability",
    "positive cash flow", "debt free", "no material litigation",
    "strong liquidity", "improved margins", "market leader",
    "exceeded expectations", "robust demand",
]

# %%
# def assign_risk_label(text: str) -> str:
#     """
#     Assigns high / medium / low risk based on keyword density.
#     Uses the combined Risk Factors + MD&A text.
#     """
#     if not text or len(text.strip()) < 50:
#         return "medium_risk"

#     total_words = max(len(text.split()), 1)

#     high_count = sum(text.count(kw) for kw in HIGH_RISK_KEYWORDS)
#     low_count  = sum(text.count(kw) for kw in LOW_RISK_KEYWORDS)

#     # Normalize per 1000 words to make it length-independent
#     high_density = (high_count / total_words) * 1000
#     low_density  = (low_count  / total_words) * 1000

#     if high_density >= 3.5:
#         return "high_risk"
#     elif low_density >= 1.5 and high_density < 1.5:
#         return "low_risk"
#     else:
#         return "medium_risk"

# %%
label_text = df_raw["clean_risk"] + " " + df_raw["clean_mda"] + " " + df_raw["clean_business"] + " " + df_raw["clean_financials"]

# %%
label_text
# Out:
# 0       risk factors management s discussion and analy...
# 1
# 2
# 3       in addition the securities markets from time t...
# 4
#                               ...
# 3495
# 3496
# 3497
# 3498
# 3499    the company may be unable to market and sell i...
# Length: 3500, dtype: object

# %%
# df_raw["label3"] = label_text.apply(assign_risk_label)

# %%
#df_raw

# %%
# !pip install pysentiment2
from pysentiment2 import LM
lm = LM()

# %%
# def assign_label1(text):
#     tokens = lm.tokenize(text)
#     score  = lm.get_score(tokens)
    
#     polarity = score["Polarity"]   # ranges from -1 to +1
    
#     if polarity < -0.3:
#         return "high_risk"
#     elif polarity > 0.1:
#         return "low_risk"
#     else:
#         return "medium_risk"

# %%
# df_raw["label2"] = label_text.apply(assign_label1)

# %%
# df_raw

# %%
def assign_risk_score(text: str) -> float:
    # if not text or len(text.strip()) < 50:
    #     return 0.0

    text = text.lower()

    # ---------- Keyword Risk ----------
    total_words = max(len(text.split()), 1)

    high_count = sum(text.count(kw) for kw in HIGH_RISK_KEYWORDS)
    low_count  = sum(text.count(kw) for kw in LOW_RISK_KEYWORDS)

    high_density = (high_count / total_words) * 1000
    low_density  = (low_count / total_words) * 1000

    keyword_score = high_density - 0.5 * low_density

    # ---------- LM Sentiment Risk ----------
    tokens = lm.tokenize(text)
    lm_score = lm.get_score(tokens)

    polarity = lm_score["Polarity"]      # -1 to +1

    sentiment_score = -polarity * 10

    # ---------- Combined ----------
    risk_score = (
        0.6 * keyword_score +
        0.4 * sentiment_score
    )

    return risk_score

# %%
df_raw["risk_score"] = label_text.apply(assign_risk_score)

q1 = df_raw["risk_score"].quantile(0.33)
q2 = df_raw["risk_score"].quantile(0.66)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df_raw["risk_score"] = label_text.apply(assign_risk_score)
#       2
#       3 q1 = df_raw["risk_score"].quantile(0.33)
#       4 q2 = df_raw["risk_score"].quantile(0.66)
#
# File ~\miniconda3\envs\env\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\miniconda3\envs\env\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\miniconda3\envs\env\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\miniconda3\envs\env\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\miniconda3\envs\env\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
# -> 2972 'Could not get source, probably due dynamically evaluated source code.'
#
# Cell In[53], line 19, in assign_risk_score(text)
#      15
#      16     keyword_score = high_density - 0.5 * low_density
#      17
#      18     # ---------- LM Sentiment Risk ----------
# ---> 19     tokens = lm.tokenize(text)
#      20     lm_score = lm.get_score(tokens)
#      21
#      22     polarity = lm_score["Polarity"]      # -1 to +1
#
# File ~\miniconda3\envs\env\Lib\site-packages\pysentiment2\base.py:68, in BaseDict.tokenize(self, text)
#      62 def tokenize(self, text):
#      63     """
#      64     :type text: str
#      65     :returns: list
#      66     """
# ---> 68     return self._tokenizer.tokenize(text)
#
# File ~\miniconda3\envs\env\Lib\site-packages\pysentiment2\utils.py:41, in Tokenizer.tokenize(self, text)
#      39 tokens = []
#      40 for t in nltk.regexp_tokenize(text.lower(), '[a-z]+'):
# ---> 41     t = self._stemmer.stem(t)
#      42     if not t in self._stopset:
#      43         tokens.append(t)
#
# File ~\miniconda3\envs\env\Lib\site-packages\nltk\stem\porter.py:673, in PorterStemmer.stem(self, word, to_lowercase)
#     671 stem = self._step1c(stem)
#     672 stem = self._step2(stem)
# --> 673 stem = self._step3(stem)
#     674 stem = self._step4(stem)
#     675 stem = self._step5a(stem)
#
# File ~\miniconda3\envs\env\Lib\site-packages\nltk\stem\porter.py:530, in PorterStemmer._step3(self, word)
#     515 def _step3(self, word):
#     516     """Implements Step 3 from "An algorithm for suffix stripping"
#     517
#     518     From the paper:
#    (...)    528         (m>0) NESS  ->                  goodness       ->  good
#     529     """
# --> 530     return self._apply_rule_list(
#     531         word,
#     532         [
#     533             ("icate", "ic", self._has_positive_measure),
#     534             ("ative", "", self._has_positive_measure),
#     535             ("alize", "al", self._has_positive_measure),
#     536             ("iciti", "ic", self._has_positive_measure),
#     537             ("ical", "ic", self._has_positive_measure),
#     538             ("ful", "", self._has_positive_measure),
#     539             ("ness", "", self._has_positive_measure),
#     540         ],
#     541     )
#
# File ~\miniconda3\envs\env\Lib\site-packages\nltk\stem\porter.py:266, in PorterStemmer._apply_rule_list(self, word, rules)
#     263     else:
#     264         # Don't try any further rules
#     265         return word
# --> 266 if word.endswith(suffix):
#     267     stem = self._replace_suffix(word, suffix, "")
#     268     if condition is None or condition(stem):
#
# KeyboardInterrupt:

# %%
def assign_label2(score):
    if score <= q1:
        return "low_risk"
    elif score <= q2:
        return "medium_risk"
    else:
        return "high_risk"

# %%
df_raw["label"] = df_raw["risk_score"].apply(assign_label2)

# %%
df_raw

# %%
# before = len(df_raw['text'])
# df_raw = df_raw[df_raw["text"].str.split().str.len() >= 30].reset_index(drop=True)
# dropped = before - len(df_raw)
# print(f"Dropped {dropped} rows with < 30 words. Remaining: {len(df_raw)} and before: {before}")

# %%
# print(before)

# %%
len(label_text)

# %%
output_cols = [
        "split",
        "company_name",          # keep for traceability if column exists
        "text",                  # combined cleaned text  → input to features.py
        "clean_risk",            # individual sections    → optional ablation
        "clean_mda",
        "clean_business",
        "clean_financials",
        "label",                 # target variable
    ]

# %%
output_cols = [c for c in output_cols if c in df_raw.columns]
df_out = df_raw[output_cols].copy()

# %%
df_out

# %%
from pathlib import Path
df_out.to_csv(Path("data.csv"), index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for key in SECTION_COLS:
    df_out[f"clean_{key}_len"] = df_out[f"clean_{key}"].str.len()/1000

# %%
df_out.hist(figsize=(20,15))

# %%
df_out["clean_mda_len"].describe()
df_out["clean_mda_len"].value_counts().head()

# %%
for col in ["clean_risk_len", "clean_business_len", "clean_financials_len","clean_mda_len"]:
    print("\n", col)
    print(df_out[col].describe())
    print("Max:", df_out[col].max())
