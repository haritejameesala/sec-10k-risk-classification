# %%
import nltk

# %%
corpus = """Hi , I am Hariteja.I am interested in AI, ML.
I am still learning.
"""
corpus
# Out:
# 'Hi , I am Hariteja.I am interested in AI, ML.\nI am still learning.\n'

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\M HARI
# [nltk_data]     TEJA\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
## Tokenization
## paragraph -> sentences
from nltk.tokenize import sent_tokenize
docs= sent_tokenize(corpus)
docs
# Out:
# ['Hi , I am Hariteja.I am interested in AI, ML.', 'I am still learning.']

# %%
## Tokenization
##paragraph --> words
##sentence --> words

from nltk.tokenize import word_tokenize
words = word_tokenize(corpus)
words
# Out:
# ['Hi',
#  ',',
#  'I',
#  'am',
#  'Hariteja.I',
#  'am',
#  'interested',
#  'in',
#  'AI',
#  ',',
#  'ML',
#  '.',
#  'I',
#  'am',
#  'still',
#  'learning',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hi',
#  ',',
#  'I',
#  'am',
#  'Hariteja',
#  '.',
#  'I',
#  'am',
#  'interested',
#  'in',
#  'AI',
#  ',',
#  'ML',
#  '.',
#  'I',
#  'am',
#  'still',
#  'learning',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
TreebankWordTokenizer().tokenize(corpus)
# Out:
# ['Hi',
#  ',',
#  'I',
#  'am',
#  'Hariteja.I',
#  'am',
#  'interested',
#  'in',
#  'AI',
#  ',',
#  'ML.',
#  'I',
#  'am',
#  'still',
#  'learning',
#  '.']
