# %%
from datasets import load_dataset

dataset = load_dataset(
    "winterForestStump/10-K_sec_filings"
)

print(dataset)
# Out:
# ...
# ---------------------------------------------------------------------------
# RemoteProtocolError                       Traceback (most recent call last)
# File ~\miniconda3\envs\env\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~\miniconda3\envs\env\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     126 with map_httpcore_exceptions():
# --> 127     for part in self._httpcore_stream:
#     128         yield part
#
# File ~\miniconda3\envs\env\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     406 self.close()
# --> 407 raise exc from None
#
# File ~\miniconda3\envs\env\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     402 try:
# --> 403     for part in self._stream:
#     404         yield part
#
# ...
