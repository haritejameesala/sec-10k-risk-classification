# %%
import pandas as pd

# %%
processed = pd.read_csv("processed.csv")

# %%
processed["clean_risk"][0]
# Out:
# 'risk factors factors that may affect future results the following risk factors and other information included in this should be carefully considered if any of the following risks occur the company s business financial condition operating results and cash flows could be materially adversely affected the risks and uncertainties described below are not the only ones the company faces additionally risks and uncertainties not presently known to the company or that it currently deems immaterial also may impair its business financial condition operating results and cash flows in the future risks relating to cambrex s business companies may discontinue or decrease their usage of cambrex s services the company has observed increasing pressure on the part of its customers to reduce costs including the use of its services and products as a result of macro economic trends and various market dynamics specifically affecting the pharmaceutical industry these customers could discontinue or decrease
# ...

# %%
processed[processed["clean_business"].str.len()> 1000]
# Out:
#                           company_name  \
# 0                         CAMBREX CORP
# 1                 ADMINISTAFF INC \DE\
# 2                    NSTAR ELECTRIC CO
# 5               Eco Energy Pumps, Inc.
# 6                         COPYTELE INC
# ...                                ...
# 2395      AMERISERV FINANCIAL INC /PA/
# 2396        AMPAL-AMERICAN ISRAEL CORP
# 2397                         GTSI CORP
# 2398          AMERICAN HOMEPATIENT INC
# 2399  PALOMAR MEDICAL TECHNOLOGIES INC
#
#                                                    text  \
# 0     risk factors factors that may affect future re...
# 1     factors that may affect future results and the...
# 2     nstar electric s future performance is subject...
# 5     risk factors risk related to our business beca...
# 6     risk factors our business involves a high degr...
# ...                                                 ...
# 2395  investors should carefully consider the risks ...
# ...

# %%
processed[processed["clean_financials"].str.len() > 200]
# Out:
#                           company_name  \
# 2                    NSTAR ELECTRIC CO
# 3             1st United Bancorp, Inc.
# 4                    Univest Tech Inc.
# 7                       YUM BRANDS INC
# 8                IMPLANT SCIENCES CORP
# ...                                ...
# 2393         Hangman Productions, Inc.
# 2394                   DIXIE GROUP INC
# 2395      AMERISERV FINANCIAL INC /PA/
# 2397                         GTSI CORP
# 2399  PALOMAR MEDICAL TECHNOLOGIES INC
#
#                                                    text  \
# 2     nstar electric s future performance is subject...
# 3     risk factors an investment in our common stock...
# 4     we have no successful history of operations ha...
# 7     risk factors you should carefully review the r...
# 8     risk factors an investment in our common stock...
# ...                                                 ...
# 2393  the company s business operations are highly s...
# ...
